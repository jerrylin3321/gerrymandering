# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from pylab import *

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
DRIVE_PATH = "/Users/hanlin/Google Drive/CS+/Data/"
def full_path(filename):
    return DRIVE_PATH + filename

# %% [markdown]
# ### Preprocessing, Initializing Variables, etc.

# %%
dist_VTD_path = full_path("acr_VTD.txt")
dist_shp_path = full_path('acr_shapefiles')

# %%
#Combine today's datasets
df2 = gpd.read_file(full_path('NCabs_VTD'))
pairings = pd.read_csv(dist_VTD_path, sep='\t', header=None).rename(columns={0:"VTD_num", 1:"district"})

# %% [markdown]
# ### Grab Comparator District

# %%
def get_comparators(orig_filepath, rank_num):
    #Initialize original district stats
    orig = pd.read_csv(orig_filepath, sep='\t', header=None)
    orig["sample_num"] = -1

    #Grab election data from main df2 DataFrame
    election_data = df2.loc[:, ['VTD_num', "EL16G_PR_D", 'EL16G_PR_R', 'EL16G_PR_T']]

    #Grab a list of compliant numbers
    compliant = pd.read_csv(full_path("ensembles_main_rank_" + str(rank_num) + "_compliantVerbose.txt"), sep='\t', header=None)
    compliant.rename(columns={0:"sample_num", 1:"is_compliant"}, inplace=True)
    compliant_nums = compliant[compliant.is_compliant==1].sample_num.tolist()

    #Takes about 5 seconds
    #Iterate through all the compliant samples and read in their data
    pd_lists = []
    for sample_num in compliant_nums:
        filepath = full_path("ensembles_main_rank_" + str(rank_num) 
                             + "_districtingMaps/districtingMap") + str(sample_num) + ".txt"
        new = pd.read_csv(filepath, sep='\t', header=None)
        new["sample_num"] = sample_num
        pd_lists.append(new)
    pd_lists.append(orig)

    #Concat and rename
    final = pd.concat(pd_lists)
    final.rename(columns={0:"VTD_num", 1:"district"}, inplace=True)

    #Join with election data
    final = final.merge(election_data, how='left', on="VTD_num")

    #Group at district level
    grouped = final.groupby(["sample_num", "district"]).sum()

    #Grouped at the district level, calculate district-level stats like dem prop and rep prop
    grouped["dem_prop"] = grouped["EL16G_PR_D"]/grouped["EL16G_PR_T"]
    grouped['rep_prop'] = grouped["EL16G_PR_R"]/grouped["EL16G_PR_T"]
    grouped['dem_win'] = 0
    grouped.loc[grouped.dem_prop > grouped.rep_prop, "dem_win"] = 1
    grouped.drop(columns=['EL16G_PR_D', 'EL16G_PR_R', 'EL16G_PR_T', 'VTD_num'], inplace=True)

    flattened = grouped.reset_index()

    #Add district-level stats to each VTD
    final2 = final.merge(flattened, how="left", left_on=['sample_num', 'district'], right_on=['sample_num', 'district'])

    orig_dst_lvl = final2.loc[final2.sample_num==-1]
    comp_dst_lvl = final2.loc[final2.sample_num!=-1]

    #Add original districting data to each comparator VTD entry — for easy calculation of differences between comparator
    final3 = comp_dst_lvl.merge(orig_dst_lvl, how="left", left_on='VTD_num', right_on='VTD_num', suffixes=('', '_orig'))
    
    #Actually, we do want orig to be labeled with column names! Since we use it later
    orig.rename(columns={0:"VTD_num", 1:"district"}, inplace=True)
    
    return final3, orig

# %%
#Why do we even need orig?
final3, orig = get_comparators(orig_filepath = dist_VTD_path, rank_num=0)

# %% [markdown]
# ### Staple Functions

# %%
def dist_level_data(VTD_data):
    districts = VTD_data.groupby('district')[['EL16G_PR_D', 'EL16G_PR_R', 'EL16G_PR_T', 'TOTPOP']].sum().reset_index()
    districts['dem_prop'] = districts.EL16G_PR_D/districts.EL16G_PR_T
    districts['rep_prop'] = districts.EL16G_PR_R/districts.EL16G_PR_T
    return districts

# %%
# Calculate the Polsby Popper compactness score
def polsby_popper(shape):
    return (4 * np.pi * shape.area) / (shape.length ** 2)

# %%
def calc_gmandered_score(df):
    dem_filter = ((df.dem_prop > df.rep_prop) & (df.dem_prop_orig < df.rep_prop_orig)) | (((df.dem_prop_orig - df.dem_prop) > PK_PCT) & (df.dem_prop > df.rep_prop))
    rep_filter = ((df.rep_prop > df.dem_prop) & (df.rep_prop_orig < df.dem_prop_orig)) | (((df.rep_prop_orig - df.rep_prop) > PK_PCT) & (df.rep_prop > df.dem_prop))


    df['dem_gmandered'] = np.where(dem_filter, df['EL16G_PR_D'], 0)
    df['rep_gmandered'] = np.where(rep_filter, df['EL16G_PR_R'], 0)
    df['tot_gmandered'] = df.dem_gmandered + df.rep_gmandered
    
    #Summing up in total and dividing by sample num is the same as grouping by and taking mean.
    return df.tot_gmandered.sum()/NUM_SAMPLE_NUM

# %%
def calc_candidates(curr_data):
    curr_data[("neighborof")] = 0
    for district in range(1, 14):
        dist_comp = curr_data.loc[curr_data.district==district, "loc_prec"].tolist()
        neighbors = set()
        neighbor_list = curr_data.loc[curr_data.district==district, "neighbors"].tolist()
        for one_neighbor_list in neighbor_list:
            for item2 in one_neighbor_list:
                neighbors.add(item2)
        neighbors = neighbors.difference(dist_comp)
        curr_data.loc[curr_data.loc_prec.isin(neighbors), "neighborof"] = district
    candidates = curr_data[curr_data.neighborof!=0]
    return candidates

# %%
def check_compact(orig_shapes, row, COMP_DEV, remove_shape, add_shape):
    dist_comp = polsby_popper(orig_shapes.loc[row.district, 'geometry'])
    neigh_comp = polsby_popper(orig_shapes.loc[int(row.neighborof),'geometry'])
    remove_comp = polsby_popper(remove_shape)
    add_comp = polsby_popper(add_shape)
    remove_dev = (dist_comp - remove_comp) / dist_comp #pos when new worse than orig
    add_dev = (neigh_comp - add_comp) / neigh_comp #pos when new worse than orig

    #print("Compactness deviations of:", remove_dev, add_dev)
    if ((remove_dev >= COMP_DEV) or (add_dev >= COMP_DEV)):
        #print("Compactness check failed!", remove_dev, add_dev)
        return False
    else:
        #print("Compactness check passed")
        return True

# %%
def check_fancy_compact(orig_pols_list, temp_pols_list, row, COMP_DEV, remove_shape, add_shape):
    remove_comp = polsby_popper(remove_shape)
    add_comp = polsby_popper(add_shape)
    temp_pols_list[row.neighborof-1] = add_comp #lists index from 0
    temp_pols_list[row.district-1] = remove_comp
    
    avg_dev = (mean(orig_pols_list) - mean(temp_pols_list))/mean(orig_pols_list) #pos when temp worse than orig
    worst_dev = (min(orig_pols_list) - min(temp_pols_list))/min(orig_pols_list) #pos when temp worse than orig
    
    if ((avg_dev >= COMP_DEV) or (worst_dev >= COMP_DEV)): #if positively deviates more than comp_dev
        return False
    else:
        return True

# %% [markdown]
# ### Run Algo

# %% [markdown]
# Data Needed: data, shapes, districts (dist-lvl data), scoredf

# %%
### STATE-SPECIFIC or unchanging CONSTANTS
NUM_DIST = 13 # Number of districts
IDEAL_POP = 733499 # Ideal population per district
PK_PCT = 0.05 # Amount of change necessary to cross packedness threshold in calc_gmandered_score_fast()
NUM_SAMPLE_NUM = final3.sample_num.nunique()

# %%
### Implementation variables
POP_DEV = 0.02 # Amount of acceptable population deviation
COMP_DEV = 0.05 # Amount of acceptable compactness deviation

# %%
### Simulated annealing specific parameters
INITPROB = 0.4 # Used to calculate initial temperature
calibrate_temp = False
STARTTEMP = 400 # If -1, we need to calculate STARTTEMP. Otherwise, use given STARTTEMP
TEMPFACTOR = 0.95 # Cooling ratio r
MINPERCENT = 0.02 # Used to test if annealing run is frozen & should be terminated
L = 355

# %%
#Initialize orig_data and orig_shapes
orig_data = df2.merge(pairings, on='VTD_num')
orig_data["neighbors"] = orig_data.my_neighbo.str.split(", ")
orig_data = orig_data[['VTD_num', 'EL16G_PR_D', 'EL16G_PR_R', 'EL16G_PR_T', 'TOTPOP', 'neighbors', 'district', 'loc_prec', 'geometry']]
orig_shapes = gpd.read_file(dist_shp_path)
if 'District' in orig_shapes.columns:
    orig_shapes.rename(columns={'District':'district'}, inplace=True)
orig_shapes.index = orig_shapes.district #The index is the exact district numbers
orig_pols_list = polsby_popper(orig_shapes).tolist()

# %%
#RERUN THIS TO FULLY RESTART ALGORITHM
# Initialize simulated annealing variables used in the algorithm
np.random.seed(0)
frozen_count = 0
temps_completed = 0
frozen = False
champ_scoredf = None
champ_data = None
iterations = 0
accepted = 0
T = STARTTEMP

orig_districts = dist_level_data(orig_data)

curr_shapes = orig_shapes.copy()
curr_scoredf = final3.copy()
#Cull the scoredf to only contain the columns we need! The copy operations will be costly otherwise
curr_scoredf = curr_scoredf[['dem_prop', 'rep_prop', 'dem_prop_orig', 'rep_prop_orig', 
                             'VTD_num', 'EL16G_PR_D', 'EL16G_PR_R', 'district_orig']]
champ_scoredf = curr_scoredf
curr_districts = orig_districts.copy()
curr_data = orig_data.copy()

count = 0
x = []
y = []

# %%
#Can pause this code block and continue later with your progress saved!
while not frozen:
    curr_iter_district = -1 
    curr_iter_neighborof = -1 
    curr_iter_gmandered = -1 
    update_slice = True
    count += 1
    if count % 25 == 0:
        score = calc_gmandered_score(curr_scoredf)
        x.append(count)
        y.append(score)

    print("============ Recalculating candidates", count, "============")
    candidates = calc_candidates(curr_data)

    for index, row in candidates.sample(frac=1).iterrows(): 
        #Simulated annealing checks
        if (iterations == L) & (calibrate_temp == False): #Note that iterations are only those candidate swaps which satisfy pop, contig, compact
            temps_completed += 1
            print('======= Simulated annealing run', temps_completed, '-=======')
            T = TEMPFACTOR * T
            if (accepted/iterations) < MINPERCENT:
                frozen_count += 1
                
            # Determine whether to reset frozen_count. Implemented slightly diff. from Johnson et. al
            curr_gmandered = calc_gmandered_score(curr_scoredf)
            champ_gmandered = calc_gmandered_score(champ_scoredf)
            if curr_gmandered < champ_gmandered:
                frozen_count = 0
                champ_scoredf = curr_scoredf
                champ_data = curr_data
                
            if frozen_count == 5:
                frozen = True
                break
            iterations = 0
            accepted = 0
        
        #Population check
        if ((curr_districts.loc[curr_districts.district == row.district, 'TOTPOP'].iloc[0] - row.TOTPOP) > (IDEAL_POP*(1-POP_DEV))) & (
            (curr_districts.loc[curr_districts.district == row.neighborof, 'TOTPOP'].iloc[0] + row.TOTPOP) < (IDEAL_POP*(1+POP_DEV))):
            pass
        else:
            continue
        
        #Determine whether to update the curr_df_slice (timesaving device)
        if (row.district != curr_iter_district) | (row.neighborof != curr_iter_neighborof) | (
            curr_iter_gmandered == -1):
            update_slice = True
            curr_iter_district = row.district
            curr_iter_neighborof = row.neighborof
            

        ### Check contiguity
        prec_shape = df2.loc[df2.loc_prec==row.loc_prec, 'geometry'].values[0]
        remove_shape = curr_shapes.loc[row.district, 'geometry'].difference(prec_shape)
        add_shape = curr_shapes.loc[int(row.neighborof), 'geometry'].union(prec_shape)

        if ((remove_shape.geom_type != 'Polygon') or (len(remove_shape.interiors) > 0)) or ((add_shape.geom_type != 'Polygon') or (len(add_shape.interiors) > 0)):
            #print("Contiguity check failed! Select new VTD to test.")
            continue
        else:
            #print("Contiguity check passed!")
            pass

        ### Check compactness
        '''if check_compact(orig_shapes, row, COMP_DEV, remove_shape, add_shape)==False:
            continue
        else:
            pass'''
        temp_pols_list = polsby_popper(curr_shapes).tolist()
        if check_fancy_compact(orig_pols_list, temp_pols_list, row, COMP_DEV, remove_shape, add_shape)==False:
            continue
        else:
            pass
        

        #=======Calc the current level of gerrymandering======
        #At this point, these are acceptable swaps, which count towards iteration & frozen.
        iterations += 1
        
        if update_slice:
            curr_scoredf_slice = curr_scoredf.loc[(curr_scoredf.district_orig==row.district)|(curr_scoredf.district_orig==row.neighborof)]
            curr_iter_gmandered = calc_gmandered_score(curr_scoredf_slice)
            update_slice = False

        #Perform the swap in data
        temp_data = curr_data.copy()
        temp_data.loc[temp_data.VTD_num == row.VTD_num, 'district'] = row.neighborof
        temp_districts = dist_level_data(temp_data)

        #Two cases
        #1. If dist/neighborof changes, then curr has just been updated. 
        #2. If dist/neighborof hasn't changed, curr_scoredf_slice will still be good from last iteration
        temp_scoredf_slice = curr_scoredf_slice.copy()

        #Perform the swap in the scoredf
        temp_scoredf_slice.loc[temp_scoredf_slice.VTD_num == row.VTD_num, 'district_orig'] = row.neighborof
        temp_scoredf_slice.loc[(temp_scoredf_slice.district_orig==row.neighborof),['dem_prop_orig', 'rep_prop_orig']] = temp_districts.loc[(temp_districts.district==row.neighborof), ['dem_prop', 'rep_prop']].iloc[0].tolist()
        temp_scoredf_slice.loc[(temp_scoredf_slice.district_orig==row.district),['dem_prop_orig', 'rep_prop_orig']] = temp_districts.loc[(temp_districts.district==row.district), ['dem_prop', 'rep_prop']].iloc[0].tolist()

        temp_gmandered = calc_gmandered_score(temp_scoredf_slice)

        if temp_gmandered < curr_iter_gmandered:
            print('good swap')
            swap = True
        elif temp_gmandered == curr_iter_gmandered:
            #Don't let zero cost swaps occur, they just repeat over and over
            swap = False
        else:
            delta = temp_gmandered-curr_iter_gmandered
            prob = math.exp((-1) * (delta) / T)
            print("Bad swap, probability of making the swap:", prob)
            swap = np.random.choice([1, 0], 1, p=[prob, 1-prob])
            if swap[0] == 1:
                print("Make swap anyways!")
                swap=True
            else:
                print('Don\'t make swap.')
                swap=False
        
        if swap == True:
            accepted += 1
            if calibrate_temp == True:
                continue
            print("swap", row.loc_prec, "VTD from", row.district, "to", row.neighborof, "base", curr_iter_gmandered, 'new', temp_gmandered)
            curr_shapes.loc[row.district, 'geometry'] = remove_shape
            curr_shapes.loc[row.neighborof, 'geometry'] = add_shape
            curr_districts = temp_districts
            curr_data = temp_data
            curr_scoredf.loc[curr_scoredf.VTD_num == row.VTD_num, 'district_orig'] = row.neighborof
            curr_scoredf.loc[(curr_scoredf.district_orig==row.neighborof),['dem_prop_orig', 'rep_prop_orig']] = temp_districts.loc[(temp_districts.district==row.neighborof), ['dem_prop', 'rep_prop']].iloc[0].tolist()
            curr_scoredf.loc[(curr_scoredf.district_orig==row.district),['dem_prop_orig', 'rep_prop_orig']] = temp_districts.loc[(temp_districts.district==row.district), ['dem_prop', 'rep_prop']].iloc[0].tolist()
            break #Break to recalculate candidates
    print()
    if calibrate_temp==True:
        print('calibration finished')
        break
else:
    print('program has ended! prolly froze, or done with calibration')
    print(accepted/iterations)
# Out:
# ============ Recalculating candidates 4443 ============
# Bad swap, probability of making the swap: 6.172387734959876e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.00044249609398555134
# Don't make swap.
# Bad swap, probability of making the swap: 0.0005649939135823555
# Don't make swap.
# Bad swap, probability of making the swap: 0.00021751326075395233
# Don't make swap.
# Bad swap, probability of making the swap: 0.00011403636140886535
# Don't make swap.
# Bad swap, probability of making the swap: 0.004499232849599718
# Don't make swap.
# Bad swap, probability of making the swap: 3.556830118020877e-11
# Don't make swap.
# Bad swap, probability of making the swap: 3.299596692544613e-11
# Don't make swap.
# Bad swap, probability of making the swap: 0.01755113480096242
# Don't make swap.
# Bad swap, probability of making the swap: 0.0005961222251753128
# Don't make swap.
# Bad swap, probability of making the swap: 5.64037863876593e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.05790900154678321
# Don't make swap.
# Bad swap, probability of making the swap: 1.279005331773303e-22
# Don't make swap.
# Bad swap, probability of making the swap: 0.0002764047844469218
# Don't make swap.
# Bad swap, probability of making the swap: 6.818388897115667e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.004759816030064959
# Don't make swap.
# Bad swap, probability of making the swap: 1.5307879042924445e-08
# Don't make swap.
# Bad swap, probability of making the swap: 1.4339238075893268e-06
# Don't make swap.
# Bad swap, probability of making the swap: 6.977215421732743e-24
# Don't make swap.
# Bad swap, probability of making the swap: 3.667046314430441e-11
# Don't make swap.
# Bad swap, probability of making the swap: 4.378562676973206e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.005264193745373805
# Don't make swap.
# Bad swap, probability of making the swap: 3.485910611018536e-06
# Don't make swap.
# Bad swap, probability of making the swap: 1.6808898718604124e-12
# Don't make swap.
# Bad swap, probability of making the swap: 0.15791479583345439
# Make swap anyways!
# swap 3718301-03 VTD from 12 to 10 base 75872.3971563981 new 75949.67582938388
#
# ============ Recalculating candidates 4444 ============
# Bad swap, probability of making the swap: 0.00021751326075395233
# Don't make swap.
# Bad swap, probability of making the swap: 1.836214454070796e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.0005961222251753128
# Don't make swap.
# Bad swap, probability of making the swap: 0.0024560989155528465
# Don't make swap.
# Bad swap, probability of making the swap: 0.004080046146139559
# Don't make swap.
# Bad swap, probability of making the swap: 3.7365464914430375e-06
# Don't make swap.
# Bad swap, probability of making the swap: 3.299596692544613e-11
# Don't make swap.
# ======= Simulated annealing run 45 -=======
# Bad swap, probability of making the swap: 0.00279932281640895
# Don't make swap.
# Bad swap, probability of making the swap: 2.4302826883116477e-06
# Don't make swap.
# good swap
# swap 3718301-03 VTD from 10 to 12 base 75949.67582938388 new 75872.3971563981
#
# ============ Recalculating candidates 4445 ============
# Bad swap, probability of making the swap: 8.304958806882321e-06
# Don't make swap.
# Bad swap, probability of making the swap: 9.264050308841867e-12
# Don't make swap.
# Bad swap, probability of making the swap: 4.4607293801327026e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.00011996246398929446
# Don't make swap.
# Bad swap, probability of making the swap: 0.04984567132350731
# Don't make swap.
# Bad swap, probability of making the swap: 7.484036399221322e-08
# Don't make swap.
# Bad swap, probability of making the swap: 2.4302826883116477e-06
# Don't make swap.
# Bad swap, probability of making the swap: 2.4433370108587798e-05
# Don't make swap.
# Bad swap, probability of making the swap: 2.8119527690186103e-18
# Don't make swap.
# Bad swap, probability of making the swap: 7.062765977123753e-07
# Don't make swap.
# Bad swap, probability of making the swap: 9.007462834466399e-24
# Don't make swap.
# Bad swap, probability of making the swap: 4.177001210617979e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.003993943924149158
# Don't make swap.
# Bad swap, probability of making the swap: 0.14329615940811533
# Don't make swap.
# Bad swap, probability of making the swap: 8.93901532926169e-08
# Don't make swap.
# Bad swap, probability of making the swap: 4.0348816476447577e-13
# Don't make swap.
# Bad swap, probability of making the swap: 1.0025800919599171e-11
# Don't make swap.
# Bad swap, probability of making the swap: 0.00014699896669955752
# Don't make swap.
# Bad swap, probability of making the swap: 9.521811420139465e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.00279932281640895
# Don't make swap.
# Bad swap, probability of making the swap: 0.005712105473572391
# Don't make swap.
# Bad swap, probability of making the swap: 2.645024788490531e-07
# Don't make swap.
# Bad swap, probability of making the swap: 3.457925294806228e-06
# Don't make swap.
# Bad swap, probability of making the swap: 2.702724936174447e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.0069723341401437145
# Make swap anyways!
# swap 37081G67 VTD from 6 to 7 base 132483.1421800948 new 132680.6625592417
#
# ============ Recalculating candidates 4446 ============
# Bad swap, probability of making the swap: 1.0353087620778181e-11
# Don't make swap.
# good swap
# swap 3718301-05 VTD from 10 to 12 base 75872.3971563981 new 75870.78483412322
#
# ============ Recalculating candidates 4447 ============
# Bad swap, probability of making the swap: 4.446463588426989e-08
# Don't make swap.
# Bad swap, probability of making the swap: 3.916877121337971e-10
# Don't make swap.
# Bad swap, probability of making the swap: 6.569678093169811e-07
# Don't make swap.
# Bad swap, probability of making the swap: 2.702724936174447e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.001694677471635437
# Don't make swap.
# Bad swap, probability of making the swap: 4.816096014069092e-08
# Don't make swap.
# Bad swap, probability of making the swap: 2.257963660346551e-05
# Don't make swap.
# Bad swap, probability of making the swap: 9.727117803215577e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.42216351689873444
# Don't make swap.
# Bad swap, probability of making the swap: 7.505543349740456e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0013870137368146688
# Don't make swap.
# Bad swap, probability of making the swap: 0.0056768237196196825
# Don't make swap.
# Bad swap, probability of making the swap: 0.09933307060910365
# Don't make swap.
# Bad swap, probability of making the swap: 1.1695948219766347e-10
# Don't make swap.
# Bad swap, probability of making the swap: 4.17700121061645e-06
# Don't make swap.
# Bad swap, probability of making the swap: 5.473414646615902e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.14707752070363983
# Don't make swap.
# Bad swap, probability of making the swap: 1.416027285359776e-12
# Don't make swap.
# Bad swap, probability of making the swap: 5.895423559027612e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.00729736369765825
# Don't make swap.
# Bad swap, probability of making the swap: 0.00019784644614670254
# Don't make swap.
# Bad swap, probability of making the swap: 6.080487427435702e-32
# Don't make swap.
# Bad swap, probability of making the swap: 1.6097917614953767e-06
# Don't make swap.
# Bad swap, probability of making the swap: 4.3132742205509156e-07
# Don't make swap.
# Bad swap, probability of making the swap: 1.0025800919599171e-11
# Don't make swap.
# Bad swap, probability of making the swap: 0.9602756038159066
# Make swap anyways!
# swap 3718301-05 VTD from 12 to 10 base 75870.78483412322 new 75872.3971563981
#
# ============ Recalculating candidates 4448 ============
# Bad swap, probability of making the swap: 4.177001210617979e-06
# Don't make swap.
# Bad swap, probability of making the swap: 5.473414646615902e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0008461498829447305
# Don't make swap.
# Bad swap, probability of making the swap: 3.970559502050291e-06
# Don't make swap.
# Bad swap, probability of making the swap: 1.0025800919599171e-11
# Don't make swap.
# Bad swap, probability of making the swap: 0.2823751384178403
# Don't make swap.
# Bad swap, probability of making the swap: 0.14329615940811533
# Don't make swap.
# Bad swap, probability of making the swap: 1.0353087620778181e-11
# Don't make swap.
# Bad swap, probability of making the swap: 3.6522359886814976e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0003033705495212862
# Don't make swap.
# Bad swap, probability of making the swap: 0.005712105473572391
# Don't make swap.
# Bad swap, probability of making the swap: 5.895423559027612e-06
# Don't make swap.
# Bad swap, probability of making the swap: 7.505543349740456e-05
# Don't make swap.
# Bad swap, probability of making the swap: 1.7991597760438016e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.0005767252658273684
# Don't make swap.
# good swap
# swap 3718301-05 VTD from 10 to 12 base 75872.3971563981 new 75870.78483412322
#
# ============ Recalculating candidates 4449 ============
# Bad swap, probability of making the swap: 3.650636023228974e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.00030168359146332403
# Don't make swap.
# Bad swap, probability of making the swap: 4.816096014069092e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.09933307060910365
# Don't make swap.
# Bad swap, probability of making the swap: 0.005619620261204421
# Don't make swap.
# Bad swap, probability of making the swap: 0.0013870137368146688
# Don't make swap.
# Bad swap, probability of making the swap: 0.00013361815314355535
# Don't make swap.
# Bad swap, probability of making the swap: 5.868791109347294e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.0002821974216291217
# Don't make swap.
# Bad swap, probability of making the swap: 2.7475599535908e-07
# Don't make swap.
# Bad swap, probability of making the swap: 3.970559502050291e-06
# Don't make swap.
# Bad swap, probability of making the swap: 4.2509828936984945e-15
# Don't make swap.
# Bad swap, probability of making the swap: 0.00038115244027335423
# Don't make swap.
# Bad swap, probability of making the swap: 6.569678093169811e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0005939505974788802
# Don't make swap.
# good swap
# swap 3715518A VTD from 8 to 9 base 62359.07298578199 new 62209.91848341232
#
# ============ Recalculating candidates 4450 ============
# Bad swap, probability of making the swap: 0.04984567132350731
# Don't make swap.
# Bad swap, probability of making the swap: 0.005619620261204421
# Don't make swap.
# Bad swap, probability of making the swap: 0.005426430494275351
# Don't make swap.
# Bad swap, probability of making the swap: 5.868791109347294e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.08773526168815132
# Don't make swap.
# Bad swap, probability of making the swap: 9.727117803215577e-06
# Don't make swap.
# Bad swap, probability of making the swap: 8.93901532926169e-08
# Don't make swap.
# Bad swap, probability of making the swap: 1.767450152927421e-05
# Don't make swap.
# Bad swap, probability of making the swap: 1.2866355175583646e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.0002821974216291217
# Don't make swap.
# Bad swap, probability of making the swap: 3.970559502050291e-06
# Don't make swap.
# Bad swap, probability of making the swap: 2.2330161281808273e-09
# Don't make swap.
# Bad swap, probability of making the swap: 5.937378833939562e-09
# Don't make swap.
# Bad swap, probability of making the swap: 2.7475599535908e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.9602756038159066
# Make swap anyways!
# swap 3718301-05 VTD from 12 to 10 base 75870.78483412322 new 75872.3971563981
#
# ============ Recalculating candidates 4451 ============
# Bad swap, probability of making the swap: 0.0035921798369734927
# Don't make swap.
# Bad swap, probability of making the swap: 9.727117803215577e-06
# Don't make swap.
# Bad swap, probability of making the swap: 8.834775390800623e-12
# Don't make swap.
# Bad swap, probability of making the swap: 3.9168771213365377e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.00013361815314355535
# Don't make swap.
# Bad swap, probability of making the swap: 0.4253748081999982
# Make swap anyways!
# swap 370379 VTD from 7 to 9 base 124768.49004739337 new 124802.49004739337
#
# ============ Recalculating candidates 4452 ============
# Bad swap, probability of making the swap: 1.4085428860331695e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009164025686127917
# Don't make swap.
# Bad swap, probability of making the swap: 0.0061613494572681955
# Don't make swap.
# Bad swap, probability of making the swap: 2.7040653198116832e-09
# Don't make swap.
# Bad swap, probability of making the swap: 3.916877121337971e-10
# Don't make swap.
# Bad swap, probability of making the swap: 3.42477857088381e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0035921798369734927
# Don't make swap.
# Bad swap, probability of making the swap: 2.282295053856033e-09
# Don't make swap.
# Bad swap, probability of making the swap: 3.753993724460278e-08
# Don't make swap.
# Bad swap, probability of making the swap: 4.216271415013023e-25
# Don't make swap.
# Bad swap, probability of making the swap: 8.994282299940489e-32
# Don't make swap.
# Bad swap, probability of making the swap: 2.1550288168593556e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.02352122452112142
# Don't make swap.
# Bad swap, probability of making the swap: 9.521811420139465e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.00019784644614684733
# Don't make swap.
# Bad swap, probability of making the swap: 0.005712105473572391
# Don't make swap.
# Bad swap, probability of making the swap: 3.4875168123926162e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.00013361815314355535
# Don't make swap.
# Bad swap, probability of making the swap: 0.0008317954194760233
# Don't make swap.
# Bad swap, probability of making the swap: 0.00933435420660562
# Make swap anyways!
# swap 3719106 VTD from 12 to 8 base 45028.21990521327 new 45214.135545023695
#
# ============ Recalculating candidates 4453 ============
# Bad swap, probability of making the swap: 4.3132742205509156e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.41380683854415334
# Don't make swap.
# Bad swap, probability of making the swap: 0.05124765493658336
# Make swap anyways!
# swap 3718307-11 VTD from 12 to 11 base 74406.41516587678 new 74524.5933649289
#
# ============ Recalculating candidates 4454 ============
# Bad swap, probability of making the swap: 0.782725581040948
# Make swap anyways!
# swap 3718513 VTD from 11 to 12 base 74524.5933649289 new 74534.33744075829
#
# ============ Recalculating candidates 4455 ============
# Bad swap, probability of making the swap: 0.0009164025686127917
# Don't make swap.
# Bad swap, probability of making the swap: 7.505543349740456e-05
# Don't make swap.
# Bad swap, probability of making the swap: 3.6522359886841705e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.33728804360974196
# Make swap anyways!
# swap 3718301-30 VTD from 12 to 11 base 74534.33744075829 new 74577.56682464456
#
# ============ Recalculating candidates 4456 ============
# Bad swap, probability of making the swap: 0.3324839513068512
# Don't make swap.
# Bad swap, probability of making the swap: 0.00029565543011350793
# Don't make swap.
# Bad swap, probability of making the swap: 7.149570956976238e-05
# Don't make swap.
# Bad swap, probability of making the swap: 2.702724936174447e-10
# Don't make swap.
# Bad swap, probability of making the swap: 4.9555693617127144e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.017088224682784207
# Don't make swap.
# Bad swap, probability of making the swap: 2.4016120720562783e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.00014696744311963052
# Don't make swap.
# Bad swap, probability of making the swap: 1.8055080107862417e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.00019784644614684733
# Don't make swap.
# good swap
# swap 3718307-11 VTD from 11 to 12 base 74577.56682464456 new 74499.39052132702
#
# ============ Recalculating candidates 4457 ============
# Bad swap, probability of making the swap: 4.779693624142928e-06
# Don't make swap.
# Bad swap, probability of making the swap: 3.6522359886841705e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0013402572525950875
# Don't make swap.
# Bad swap, probability of making the swap: 1.368546285303562e-16
# Don't make swap.
# Bad swap, probability of making the swap: 3.698903373737029e-06
# Don't make swap.
# Bad swap, probability of making the swap: 2.285300571923758e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.00013361815314355535
# Don't make swap.
# Bad swap, probability of making the swap: 9.727117803222696e-06
# Don't make swap.
# Bad swap, probability of making the swap: 8.11244561359223e-05
# Don't make swap.
# Bad swap, probability of making the swap: 1.7910142350271373e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.00031635724162064127
# Don't make swap.
# Bad swap, probability of making the swap: 9.110370590099439e-07
# Don't make swap.
# Bad swap, probability of making the swap: 1.8055080107862417e-05
# Don't make swap.
# Bad swap, probability of making the swap: 4.216271415013023e-25
# Don't make swap.
# Bad swap, probability of making the swap: 2.3526921341641194e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.00030735088479192974
# Don't make swap.
# Bad swap, probability of making the swap: 0.00010376958580726111
# Don't make swap.
# Bad swap, probability of making the swap: 0.0007373260517463295
# Don't make swap.
# Bad swap, probability of making the swap: 0.5203003600876287
# Make swap anyways!
# swap 3718301-13 VTD from 12 to 10 base 75581.25308056873 new 75607.24075829383
#
# ============ Recalculating candidates 4458 ============
# Bad swap, probability of making the swap: 0.020680126126716457
# Don't make swap.
# Bad swap, probability of making the swap: 1.759759256528191e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.05187304883741241
# Don't make swap.
# Bad swap, probability of making the swap: 0.005426430494279323
# Don't make swap.
# Bad swap, probability of making the swap: 4.0348816476447577e-13
# Don't make swap.
# Bad swap, probability of making the swap: 0.08773526168815132
# Make swap anyways!
# swap 3715517 VTD from 8 to 9 base 62831.28720379147 new 62928.07962085308
#
# ============ Recalculating candidates 4459 ============
# Bad swap, probability of making the swap: 5.972571785602881e-09
# Don't make swap.
# Bad swap, probability of making the swap: 3.970559502050291e-06
# Don't make swap.
# Bad swap, probability of making the swap: 6.071505017646257e-06
# Don't make swap.
# Bad swap, probability of making the swap: 1.368546285303562e-16
# Don't make swap.
# Bad swap, probability of making the swap: 3.820835496205549e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.02894482989788316
# Don't make swap.
# Bad swap, probability of making the swap: 1.4815940175594487e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.017088224682784207
# Don't make swap.
# Bad swap, probability of making the swap: 7.505543349740456e-05
# Don't make swap.
# Bad swap, probability of making the swap: 4.0348816476447577e-13
# Don't make swap.
# Bad swap, probability of making the swap: 0.00013361815314355535
# Don't make swap.
# Bad swap, probability of making the swap: 3.62599343444556e-09
# Don't make swap.
# Bad swap, probability of making the swap: 1.0025800919599171e-11
# Don't make swap.
# Bad swap, probability of making the swap: 3.916877121337971e-10
# Don't make swap.
# Bad swap, probability of making the swap: 9.727117803222696e-06
# Don't make swap.
# Bad swap, probability of making the swap: 1.0950772195918495e-07
# Don't make swap.
# Bad swap, probability of making the swap: 1.759759256528191e-05
# Don't make swap.
# Bad swap, probability of making the swap: 8.834775390800623e-12
# Don't make swap.
# Bad swap, probability of making the swap: 4.9555693617127144e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.005619620261208528
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009164025686127917
# Don't make swap.
# Bad swap, probability of making the swap: 0.31593097399508824
# Make swap anyways!
# swap 371854 VTD from 11 to 12 base 73971.16018957346 new 74016.99146919431
#
# ============ Recalculating candidates 4460 ============
# Bad swap, probability of making the swap: 0.0014544769827893379
# Don't make swap.
# Bad swap, probability of making the swap: 0.005676823719623837
# Don't make swap.
# Bad swap, probability of making the swap: 0.0061613494572681955
# Don't make swap.
# Bad swap, probability of making the swap: 4.423278055373449e-06
# Don't make swap.
# Bad swap, probability of making the swap: 8.834775390800623e-12
# Don't make swap.
# Bad swap, probability of making the swap: 0.014320123918251288
# Don't make swap.
# Bad swap, probability of making the swap: 0.005426430494279323
# Don't make swap.
# Bad swap, probability of making the swap: 0.0061869501135320285
# Don't make swap.
# Bad swap, probability of making the swap: 8.64192336041273e-06
# Don't make swap.
# Bad swap, probability of making the swap: 8.487504639971979e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.0003016835914635448
# Don't make swap.
# Bad swap, probability of making the swap: 4.390992356476257e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.1893336641406412
# Don't make swap.
# Bad swap, probability of making the swap: 1.4341628066884247e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.004346832557675448
# Don't make swap.
# Bad swap, probability of making the swap: 3.5082371496765485e-12
# Don't make swap.
# Bad swap, probability of making the swap: 7.70397005124281e-05
# Don't make swap.
# Bad swap, probability of making the swap: 4.9555693617127144e-08
# Don't make swap.
# Bad swap, probability of making the swap: 9.007462834466399e-24
# Don't make swap.
# Bad swap, probability of making the swap: 3.6522359886841705e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009116325181693299
# Don't make swap.
# Bad swap, probability of making the swap: 1.368546285303562e-16
# Don't make swap.
# Bad swap, probability of making the swap: 0.06797740257757548
# Don't make swap.
# Bad swap, probability of making the swap: 5.222177135781615e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009164025686127917
# Don't make swap.
# Bad swap, probability of making the swap: 4.216271415013023e-25
# Don't make swap.
# good swap
# swap 371854 VTD from 12 to 11 base 74016.99146919431 new 73971.16018957346
#
# ============ Recalculating candidates 4461 ============
# Bad swap, probability of making the swap: 3.62599343444556e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.7309827513864634
# Don't make swap.
# Bad swap, probability of making the swap: 5.972571785602881e-09
# Don't make swap.
# Bad swap, probability of making the swap: 1.368546285303562e-16
# Don't make swap.
# Bad swap, probability of making the swap: 0.00029565543011350793
# Don't make swap.
# Bad swap, probability of making the swap: 0.020680126126716457
# Don't make swap.
# Bad swap, probability of making the swap: 8.834775390800623e-12
# Don't make swap.
# Bad swap, probability of making the swap: 4.779693624142928e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009164025686127917
# Don't make swap.
# Bad swap, probability of making the swap: 1.3969908524727176e-07
# Don't make swap.
# Bad swap, probability of making the swap: 4.216271415013023e-25
# Don't make swap.
# Bad swap, probability of making the swap: 0.000569459926139765
# Don't make swap.
# Bad swap, probability of making the swap: 0.00019784644614684733
# Don't make swap.
# Bad swap, probability of making the swap: 7.505543349740456e-05
# Don't make swap.
# good swap
# swap 3718301-13 VTD from 10 to 12 base 75607.24075829383 new 75581.25308056873
#
# ============ Recalculating candidates 4462 ============
# Bad swap, probability of making the swap: 1.8055080107862417e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.005619620261208528
# Don't make swap.
# Bad swap, probability of making the swap: 0.005640953285680033
# Don't make swap.
# Bad swap, probability of making the swap: 6.198398909901445e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.00010376958580726111
# Don't make swap.
# Bad swap, probability of making the swap: 4.779693624142928e-06
# Don't make swap.
# good swap
# swap 3715517 VTD from 9 to 8 base 62928.07962085308 new 62831.28720379147
#
# ============ Recalculating candidates 4463 ============
# Bad swap, probability of making the swap: 0.00030735088479192974
# Don't make swap.
# Bad swap, probability of making the swap: 0.03725727986206521
# Don't make swap.
# Bad swap, probability of making the swap: 1.0025800919599171e-11
# Don't make swap.
# Bad swap, probability of making the swap: 9.727117803222696e-06
# Don't make swap.
# Bad swap, probability of making the swap: 4.9555693617127144e-08
# Don't make swap.
# Bad swap, probability of making the swap: 6.198398909901445e-06
# Don't make swap.
# Bad swap, probability of making the swap: 8.834775390800623e-12
# Don't make swap.
# Bad swap, probability of making the swap: 2.285300571923758e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.005426430494279323
# Don't make swap.
# Bad swap, probability of making the swap: 3.698903373737029e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.8842751675443343
# Make swap anyways!
# swap 3718513 VTD from 12 to 11 base 74499.39052132702 new 74504.28246445497
#
# ============ Recalculating candidates 4464 ============
# Bad swap, probability of making the swap: 0.001694677471635437
# Don't make swap.
# Bad swap, probability of making the swap: 6.774318362133824e-08
# Don't make swap.
# Bad swap, probability of making the swap: 8.834775390800623e-12
# Don't make swap.
# Bad swap, probability of making the swap: 9.727117803222696e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.00022738822792916306
# Don't make swap.
# Bad swap, probability of making the swap: 1.3939850572436623e-05
# Don't make swap.
# Bad swap, probability of making the swap: 2.319879204757441e-06
# Don't make swap.
# Bad swap, probability of making the swap: 1.0025800919599171e-11
# Don't make swap.
# Bad swap, probability of making the swap: 3.767563806671742e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.00019784644614684733
# Don't make swap.
# good swap
# swap 3718513 VTD from 11 to 12 base 74504.28246445497 new 74499.39052132702
#
# ============ Recalculating candidates 4465 ============
# Bad swap, probability of making the swap: 0.1400985995880448
# Don't make swap.
# Bad swap, probability of making the swap: 9.007462834466399e-24
# Don't make swap.
# Bad swap, probability of making the swap: 1.8055080107862417e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.005619620261208528
# Don't make swap.
# Bad swap, probability of making the swap: 4.9555693617127144e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.00029565543011350793
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009164025686127917
# Don't make swap.
# Bad swap, probability of making the swap: 0.0013402572525950875
# Don't make swap.
# Bad swap, probability of making the swap: 9.110370590099439e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0007373260517463295
# Don't make swap.
# Bad swap, probability of making the swap: 3.970559502050291e-06
# Don't make swap.
# Bad swap, probability of making the swap: 2.285300571923758e-05
# Don't make swap.
# Bad swap, probability of making the swap: 7.505543349740456e-05
# Don't make swap.
# Bad swap, probability of making the swap: 4.3132742205509156e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.5787272821175369
# Make swap anyways!
# swap 3718301-03 VTD from 12 to 10 base 75581.25308056873 new 75603.00758293839
#
# ============ Recalculating candidates 4466 ============
# Bad swap, probability of making the swap: 3.130141796725435e-05
# Don't make swap.
# Bad swap, probability of making the swap: 2.255779460697272e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.02580771932075924
# Don't make swap.
# Bad swap, probability of making the swap: 4.216271415013023e-25
# Don't make swap.
# Bad swap, probability of making the swap: 1.8055080107862417e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009164025686127917
# Don't make swap.
# Bad swap, probability of making the swap: 7.505543349740456e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0016121111842962393
# Don't make swap.
# Bad swap, probability of making the swap: 0.005426430494279323
# Don't make swap.
# Bad swap, probability of making the swap: 2.6376604180217813e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.00029565543011350793
# Don't make swap.
# Bad swap, probability of making the swap: 4.9555693617127144e-08
# Don't make swap.
# good swap
# swap 3719106 VTD from 8 to 12 base 45006.0028436019 new 44947.007582938386
#
# ============ Recalculating candidates 4467 ============
# Bad swap, probability of making the swap: 9.007462834466399e-24
# Don't make swap.
# Bad swap, probability of making the swap: 7.252006237796189e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.30966239772753396
# Don't make swap.
# Bad swap, probability of making the swap: 0.0013402572525950875
# Don't make swap.
# Bad swap, probability of making the swap: 7.88597226332774e-30
# Don't make swap.
# Bad swap, probability of making the swap: 0.07496144694267291
# Don't make swap.
# Bad swap, probability of making the swap: 2.6376604180217813e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.8842751675440108
# Make swap anyways!
# swap 3718513 VTD from 12 to 11 base 74709.32227488152 new 74714.21421800948
#
# ============ Recalculating candidates 4468 ============
# Bad swap, probability of making the swap: 5.895423559027612e-06
# Don't make swap.
# Bad swap, probability of making the swap: 3.6522359886841705e-07
# Don't make swap.
# good swap
# swap 3718513 VTD from 11 to 12 base 74714.21421800948 new 74709.32227488152
#
# ============ Recalculating candidates 4469 ============
# Bad swap, probability of making the swap: 3.6887635319440714e-05
# Don't make swap.
# Bad swap, probability of making the swap: 2.702724936174447e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.048257275018278686
# Don't make swap.
# good swap
# swap 371854 VTD from 11 to 12 base 74709.32227488152 new 74670.87772511848
#
# ============ Recalculating candidates 4470 ============
# Bad swap, probability of making the swap: 4.9555693617127144e-08
# Don't make swap.
# Bad swap, probability of making the swap: 7.191777618984167e-05
# Don't make swap.
# Bad swap, probability of making the swap: 3.390995410909693e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0013870137368146688
# Don't make swap.
# Bad swap, probability of making the swap: 3.5082371496765485e-12
# Don't make swap.
# Bad swap, probability of making the swap: 4.3132742205509156e-07
# Don't make swap.
# Bad swap, probability of making the swap: 1.8764551796622772e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.1976175332440906
# Don't make swap.
# Bad swap, probability of making the swap: 0.31148303098684255
# Don't make swap.
# Bad swap, probability of making the swap: 0.5903441248507013
# Make swap anyways!
# swap 3718307-03 VTD from 12 to 11 base 74670.87772511848 new 74691.84170616114
#
# ============ Recalculating candidates 4471 ============
# Bad swap, probability of making the swap: 4.216271415013023e-25
# Don't make swap.
# Bad swap, probability of making the swap: 0.0008317954194760233
# Don't make swap.
# Bad swap, probability of making the swap: 0.00019784644614684733
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009838225357052175
# Don't make swap.
# Bad swap, probability of making the swap: 0.0013870137368146688
# Don't make swap.
# Bad swap, probability of making the swap: 0.00029565543011350793
# Don't make swap.
# Bad swap, probability of making the swap: 5.353653011782934e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.001694677471635437
# Don't make swap.
# good swap
# swap 3705750 VTD from 2 to 6 base 92609.24170616113 new 92256.89573459716
#
# ============ Recalculating candidates 4472 ============
# Bad swap, probability of making the swap: 0.00013361815314355535
# Don't make swap.
# Bad swap, probability of making the swap: 6.792511945418867e-16
# Don't make swap.
# Bad swap, probability of making the swap: 0.0006160937438955271
# Don't make swap.
# Bad swap, probability of making the swap: 4.0348816476447577e-13
# Don't make swap.
# Bad swap, probability of making the swap: 0.0006811423988213252
# Don't make swap.
# Bad swap, probability of making the swap: 3.641546598507659e-07
# Don't make swap.
# Bad swap, probability of making the swap: 3.3950695485199493e-07
# Don't make swap.
# Bad swap, probability of making the swap: 3.179531676237993e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.0010633242746171236
# Don't make swap.
# Bad swap, probability of making the swap: 4.216271415013023e-25
# Don't make swap.
# Bad swap, probability of making the swap: 5.120343466984636e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.0001422061735048816
# Don't make swap.
# Bad swap, probability of making the swap: 2.813431559739286e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.08773526168815132
# Don't make swap.
# Bad swap, probability of making the swap: 0.01556868771238644
# Don't make swap.
# good swap
# swap 3718301-30 VTD from 11 to 12 base 74691.84170616114 new 74651.38862559242
#
# ============ Recalculating candidates 4473 ============
# Bad swap, probability of making the swap: 6.713188949938775e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.0010633242746171236
# Don't make swap.
# Bad swap, probability of making the swap: 4.216271415013023e-25
# Don't make swap.
# Bad swap, probability of making the swap: 6.792511945418867e-16
# Don't make swap.
# Bad swap, probability of making the swap: 6.989393752589332e-11
# Don't make swap.
# Bad swap, probability of making the swap: 3.641546598507659e-07
# Don't make swap.
# Bad swap, probability of making the swap: 3.4875168123926162e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.36167122032655674
# Don't make swap.
# ======= Simulated annealing run 46 -=======
# Bad swap, probability of making the swap: 0.011326843296055933
# Don't make swap.
# good swap
# swap 37003B1 VTD from 4 to 2 base 75992.25592417062 new 75879.28530805687
#
# ============ Recalculating candidates 4474 ============
# Bad swap, probability of making the swap: 0.014477925912315155
# Don't make swap.
# Bad swap, probability of making the swap: 2.041438606517881e-11
# Don't make swap.
# Bad swap, probability of making the swap: 0.012716677323029734
# Don't make swap.
# Bad swap, probability of making the swap: 1.462710534516284e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.05030527780035522
# Don't make swap.
# Bad swap, probability of making the swap: 9.132782343265866e-07
# Don't make swap.
# Bad swap, probability of making the swap: 1.479579715987868e-05
# Don't make swap.
# Bad swap, probability of making the swap: 1.0807275481674928e-16
# Don't make swap.
# Bad swap, probability of making the swap: 0.20145618303775104
# Don't make swap.
# Bad swap, probability of making the swap: 8.03791415244272e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0047033371357029265
# Don't make swap.
# Bad swap, probability of making the swap: 2.3719535728019958e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.0007416080768239197
# Don't make swap.
# Bad swap, probability of making the swap: 1.5411363484838788e-05
# Don't make swap.
# Bad swap, probability of making the swap: 1.251369568552495e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.006954482660015624
# Don't make swap.
# Bad swap, probability of making the swap: 0.013997612465334234
# Don't make swap.
# Bad swap, probability of making the swap: 0.019308444674266793
# Don't make swap.
# good swap
# swap 37067042 VTD from 2 to 6 base 93442.79620853081 new 93322.38957345972
#
# ============ Recalculating candidates 4475 ============
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 0.07718835116664277
# Don't make swap.
# Bad swap, probability of making the swap: 3.8336049125390695e-21
# Don't make swap.
# Bad swap, probability of making the swap: 7.56653491933088e-24
# Don't make swap.
# Bad swap, probability of making the swap: 2.041438606517881e-11
# Don't make swap.
# Bad swap, probability of making the swap: 1.0912843705633785e-08
# Don't make swap.
# Bad swap, probability of making the swap: 1.0356260037516921e-07
# Don't make swap.
# Bad swap, probability of making the swap: 1.462710534516284e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# Bad swap, probability of making the swap: 0.0047033371357029265
# Don't make swap.
# good swap
# swap 3718301-03 VTD from 10 to 12 base 76036.89004739336 new 75954.92606635072
#
# ============ Recalculating candidates 4476 ============
# Bad swap, probability of making the swap: 6.815950546689353e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.002959634854936243
# Don't make swap.
# Bad swap, probability of making the swap: 1.862976885933143e-09
# Don't make swap.
# Bad swap, probability of making the swap: 1.0912843705633785e-08
# Don't make swap.
# Bad swap, probability of making the swap: 2.874242705103238e-05
# Don't make swap.
# Bad swap, probability of making the swap: 8.03791415244272e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.20441882583671767
# Don't make swap.
# Bad swap, probability of making the swap: 0.019308444674266793
# Don't make swap.
# Bad swap, probability of making the swap: 7.551401527607641e-06
# Don't make swap.
# Bad swap, probability of making the swap: 4.987541171528429e-19
# Don't make swap.
# Bad swap, probability of making the swap: 0.11428177278154511
# Don't make swap.
# Bad swap, probability of making the swap: 3.5114723262766795e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.015839028353494794
# Don't make swap.
# Bad swap, probability of making the swap: 3.8336049125390695e-21
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# Bad swap, probability of making the swap: 3.24165883554847e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 4.191597580244834e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.00025531242741352054
# Don't make swap.
# Bad swap, probability of making the swap: 0.13122739554044155
# Make swap anyways!
# swap 37045KM2 VTD from 1 to 4 base 42844.49004739337 new 42921.22938388625
#
# ============ Recalculating candidates 4477 ============
# Bad swap, probability of making the swap: 7.551401527607641e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.10899838289762559
# Don't make swap.
# Bad swap, probability of making the swap: 1.0912843705633785e-08
# Don't make swap.
# Bad swap, probability of making the swap: 7.517935803434337e-07
# Don't make swap.
# Bad swap, probability of making the swap: 7.566534919325073e-24
# Don't make swap.
# Bad swap, probability of making the swap: 3.4594293533325214e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.0023326758628198032
# Don't make swap.
# Bad swap, probability of making the swap: 4.191597580244834e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0033607627829455615
# Don't make swap.
# Bad swap, probability of making the swap: 0.015839028353494794
# Don't make swap.
# Bad swap, probability of making the swap: 4.318597032525305e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.07718835116664277
# Don't make swap.
# Bad swap, probability of making the swap: 3.0072104469876495e-07
# Don't make swap.
# Bad swap, probability of making the swap: 9.286358363348409e-10
# Don't make swap.
# Bad swap, probability of making the swap: 1.251369568552495e-09
# Don't make swap.
# Bad swap, probability of making the swap: 6.053644104558971e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.00026127292270724465
# Don't make swap.
# Bad swap, probability of making the swap: 1.0356260037516921e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.11428177278154511
# Make swap anyways!
# swap 3718301-03 VTD from 12 to 10 base 75954.92606635072 new 76036.89004739336
#
# ============ Recalculating candidates 4478 ============
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# Bad swap, probability of making the swap: 0.0020198175272416064
# Don't make swap.
# Bad swap, probability of making the swap: 1.0912843705633785e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.10899838289762559
# Don't make swap.
# Bad swap, probability of making the swap: 4.987541171528429e-19
# Don't make swap.
# Bad swap, probability of making the swap: 0.00015714710826928696
# Don't make swap.
# Bad swap, probability of making the swap: 7.781590261394436e-05
# Don't make swap.
# good swap
# swap 3718301-03 VTD from 10 to 12 base 76036.89004739336 new 75954.92606635072
#
# ============ Recalculating candidates 4479 ============
# Bad swap, probability of making the swap: 0.07718835116664277
# Don't make swap.
# Bad swap, probability of making the swap: 9.286358363348409e-10
# Don't make swap.
# Bad swap, probability of making the swap: 1.251369568552495e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# Bad swap, probability of making the swap: 0.015839028353494794
# Don't make swap.
# good swap
# swap 37045KM2 VTD from 4 to 1 base 42921.22938388625 new 42844.49004739337
#
# ============ Recalculating candidates 4480 ============
# Bad swap, probability of making the swap: 0.3993932094128793
# Make swap anyways!
# swap 3718301-05 VTD from 10 to 12 base 75954.92606635072 new 75989.60758293839
#
# ============ Recalculating candidates 4481 ============
# Bad swap, probability of making the swap: 7.517935803434337e-07
# Don't make swap.
# Bad swap, probability of making the swap: 6.194971800827601e-09
# Don't make swap.
# Bad swap, probability of making the swap: 7.857669915799314e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.20441882583671767
# Don't make swap.
# Bad swap, probability of making the swap: 0.015839028353494794
# Don't make swap.
# Bad swap, probability of making the swap: 1.0912843705633785e-08
# Don't make swap.
# Bad swap, probability of making the swap: 2.034196830263344e-06
# Don't make swap.
# Bad swap, probability of making the swap: 8.030645630262466e-06
# Don't make swap.
# Bad swap, probability of making the swap: 3.4594293533325214e-10
# Don't make swap.
# Bad swap, probability of making the swap: 1.929769638014038e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.002738897491204332
# Don't make swap.
# Bad swap, probability of making the swap: 4.789038501509391e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.019308444674266793
# Don't make swap.
# Bad swap, probability of making the swap: 1.0356260037516921e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.13122739554044155
# Don't make swap.
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 7.259329348869278e-14
# Don't make swap.
# Bad swap, probability of making the swap: 0.0004400627350636115
# Don't make swap.
# good swap
# swap 3718301-05 VTD from 12 to 10 base 75989.60758293839 new 75954.92606635072
#
# ============ Recalculating candidates 4482 ============
# Bad swap, probability of making the swap: 4.987541171528429e-19
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# Bad swap, probability of making the swap: 0.043396927806222924
# Don't make swap.
# Bad swap, probability of making the swap: 0.002037270829787968
# Don't make swap.
# Bad swap, probability of making the swap: 0.00025531242741352054
# Don't make swap.
# Bad swap, probability of making the swap: 5.3903604281696137e-14
# Don't make swap.
# Bad swap, probability of making the swap: 0.0004400627350636115
# Don't make swap.
# Bad swap, probability of making the swap: 0.11428177278154511
# Don't make swap.
# Bad swap, probability of making the swap: 3.5114723262766795e-06
# Don't make swap.
# Bad swap, probability of making the swap: 7.56653491933088e-24
# Don't make swap.
# Bad swap, probability of making the swap: 8.03791415244272e-05
# Don't make swap.
# Bad swap, probability of making the swap: 6.815950546689353e-05
# Don't make swap.
# Bad swap, probability of making the swap: 1.7787309216041817e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.0003485245630443646
# Don't make swap.
# Bad swap, probability of making the swap: 7.551401527607641e-06
# Don't make swap.
# Bad swap, probability of making the swap: 7.517935803434337e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 6.194971800827601e-09
# Don't make swap.
# Bad swap, probability of making the swap: 2.874242705103238e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.015839028353494794
# Don't make swap.
# Bad swap, probability of making the swap: 9.189928071386978e-12
# Don't make swap.
# Bad swap, probability of making the swap: 0.3993932094128793
# Make swap anyways!
# swap 3718301-05 VTD from 10 to 12 base 75954.92606635072 new 75989.60758293839
#
# ============ Recalculating candidates 4483 ============
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 1.929769638014038e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.07718835116664277
# Don't make swap.
# Bad swap, probability of making the swap: 3.4594293533325214e-10
# Don't make swap.
# Bad swap, probability of making the swap: 7.714731843890759e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.002738897491204332
# Don't make swap.
# Bad swap, probability of making the swap: 0.0033607627829455615
# Don't make swap.
# Bad swap, probability of making the swap: 3.8336049125390695e-21
# Don't make swap.
# Bad swap, probability of making the swap: 2.2263744089088e-09
# Don't make swap.
# Bad swap, probability of making the swap: 9.286358363348409e-10
# Don't make swap.
# Bad swap, probability of making the swap: 8.03791415244272e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0004400627350636115
# Don't make swap.
# Bad swap, probability of making the swap: 0.20441882583671767
# Don't make swap.
# Bad swap, probability of making the swap: 1.251369568552495e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.031155792325071166
# Don't make swap.
# Bad swap, probability of making the swap: 5.599197114944646e-09
# Don't make swap.
# Bad swap, probability of making the swap: 1.0912843705633785e-08
# Don't make swap.
# Bad swap, probability of making the swap: 8.030645630262466e-06
# Don't make swap.
# Bad swap, probability of making the swap: 7.551401527607641e-06
# Don't make swap.
# Bad swap, probability of making the swap: 7.259329348869278e-14
# Don't make swap.
# Bad swap, probability of making the swap: 1.0356260037516921e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.005264578350767866
# Don't make swap.
# Bad swap, probability of making the swap: 7.857669915799314e-07
# Don't make swap.
# Bad swap, probability of making the swap: 2.034196830263344e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.00025531242741352054
# Don't make swap.
# Bad swap, probability of making the swap: 7.517935803434337e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# good swap
# swap 3718301-05 VTD from 12 to 10 base 75989.60758293839 new 75954.92606635072
#
# ============ Recalculating candidates 4484 ============
# Bad swap, probability of making the swap: 3.4594293533325214e-10
# Don't make swap.
# Bad swap, probability of making the swap: 8.030645630262466e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.019308444674266793
# Don't make swap.
# Bad swap, probability of making the swap: 0.002959634854936243
# Don't make swap.
# Bad swap, probability of making the swap: 7.56653491933088e-24
# Don't make swap.
# Bad swap, probability of making the swap: 3.0072104469876495e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# Bad swap, probability of making the swap: 9.189928071386978e-12
# Don't make swap.
# Bad swap, probability of making the swap: 1.0356260037516921e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 0.002037270829787968
# Don't make swap.
# Bad swap, probability of making the swap: 0.005264578350767866
# Don't make swap.
# Bad swap, probability of making the swap: 0.13122739554044155
# Make swap anyways!
# swap 37045KM2 VTD from 1 to 4 base 42844.49004739337 new 42921.22938388625
#
# ============ Recalculating candidates 4485 ============
# Bad swap, probability of making the swap: 0.00015714710826928696
# Don't make swap.
# Bad swap, probability of making the swap: 0.07718835116664277
# Don't make swap.
# Bad swap, probability of making the swap: 0.0003485245630443646
# Don't make swap.
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 1.862976885933143e-09
# Don't make swap.
# Bad swap, probability of making the swap: 1.4944630332026856e-20
# Don't make swap.
# Bad swap, probability of making the swap: 3.059339156570147e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.002037270829787968
# Don't make swap.
# Bad swap, probability of making the swap: 3.4594293533325214e-10
# Don't make swap.
# Bad swap, probability of making the swap: 7.551401527607641e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.0033607627829455615
# Don't make swap.
# Bad swap, probability of making the swap: 1.0356260037516921e-07
# Don't make swap.
# Bad swap, probability of making the swap: 6.815950546689353e-05
# Don't make swap.
# Bad swap, probability of making the swap: 1.251369568552495e-09
# Don't make swap.
# Bad swap, probability of making the swap: 6.053644104558971e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.10899838289762559
# Don't make swap.
# Bad swap, probability of making the swap: 0.20441882583671767
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# Bad swap, probability of making the swap: 1.7787309216041817e-06
# Don't make swap.
# Bad swap, probability of making the swap: 4.191597580244834e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.005264578350767866
# Don't make swap.
# Bad swap, probability of making the swap: 0.00030242460317841854
# Don't make swap.
# Bad swap, probability of making the swap: 7.566534919325073e-24
# Don't make swap.
# Bad swap, probability of making the swap: 0.043396927806222924
# Don't make swap.
# Bad swap, probability of making the swap: 0.0004400627350636115
# Don't make swap.
# Bad swap, probability of making the swap: 0.002959634854936243
# Don't make swap.
# Bad swap, probability of making the swap: 7.517935803434337e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.00026127292270724465
# Don't make swap.
# Bad swap, probability of making the swap: 0.00024962562959443595
# Don't make swap.
# Bad swap, probability of making the swap: 9.286358363348409e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.11428177278154511
# Don't make swap.
# Bad swap, probability of making the swap: 1.2418031418946561e-08
# Don't make swap.
# Bad swap, probability of making the swap: 2.874242705103238e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.0023326758628198032
# Don't make swap.
# Bad swap, probability of making the swap: 3.5114723262766795e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.3993932094128793
# Don't make swap.
# good swap
# swap 37045KM2 VTD from 4 to 1 base 42921.22938388625 new 42844.49004739337
#
# ============ Recalculating candidates 4486 ============
# Bad swap, probability of making the swap: 1.0912843705633785e-08
# Don't make swap.
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 0.13122739554044155
# Don't make swap.
# Bad swap, probability of making the swap: 1.0356260037516921e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.043396927806222924
# Don't make swap.
# Bad swap, probability of making the swap: 5.3903604281696137e-14
# Don't make swap.
# Bad swap, probability of making the swap: 3.5114723262766795e-06
# Don't make swap.
# Bad swap, probability of making the swap: 1.251369568552495e-09
# Don't make swap.
# Bad swap, probability of making the swap: 9.286358363348409e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.0003485245630443646
# Don't make swap.
# Bad swap, probability of making the swap: 0.00025531242741352054
# Don't make swap.
# Bad swap, probability of making the swap: 0.3993932094128793
# Make swap anyways!
# swap 3718301-05 VTD from 10 to 12 base 75954.92606635072 new 75989.60758293839
#
# ============ Recalculating candidates 4487 ============
# Bad swap, probability of making the swap: 5.599197114944646e-09
# Don't make swap.
# Bad swap, probability of making the swap: 0.00025531242741352054
# Don't make swap.
# Bad swap, probability of making the swap: 0.07718835116664277
# Don't make swap.
# Bad swap, probability of making the swap: 0.005264578350767866
# Don't make swap.
# Bad swap, probability of making the swap: 3.4594293533325214e-10
# Don't make swap.
# Bad swap, probability of making the swap: 0.0009176458749422596
# Don't make swap.
# Bad swap, probability of making the swap: 9.189928071386978e-12
# Don't make swap.
# Bad swap, probability of making the swap: 0.002037270829787968
# Don't make swap.
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 7.857669915799314e-07
# Don't make swap.
# Bad swap, probability of making the swap: 1.251369568552495e-09
# Don't make swap.
# Bad swap, probability of making the swap: 1.572335943520621e-05
# Don't make swap.
# Bad swap, probability of making the swap: 4.789038501509391e-05
# Don't make swap.
# Bad swap, probability of making the swap: 0.019308444674266793
# Don't make swap.
# Bad swap, probability of making the swap: 3.8336049125390695e-21
# Don't make swap.
# good swap
# swap 3718301-05 VTD from 12 to 10 base 75989.60758293839 new 75954.92606635072
#
# ============ Recalculating candidates 4488 ============
# Bad swap, probability of making the swap: 3.0072104469876495e-07
# Don't make swap.
# Bad swap, probability of making the swap: 1.251369568552495e-09
# Don't make swap.
# Bad swap, probability of making the swap: 6.815950546689353e-05
# Don't make swap.
# Bad swap, probability of making the swap: 8.03791415244272e-05
# Don't make swap.
# Bad swap, probability of making the swap: 1.7787309216041817e-06
# Don't make swap.
# Bad swap, probability of making the swap: 0.005264578350767866
# Don't make swap.
# Bad swap, probability of making the swap: 0.002037270829787968
# Don't make swap.
# Bad swap, probability of making the swap: 0.0003485245630443646
# Don't make swap.
# Bad swap, probability of making the swap: 0.11428177278154511
# Don't make swap.
# Bad swap, probability of making the swap: 9.189928071386978e-12
# Don't make swap.
# Bad swap, probability of making the swap: 1.0356260037516921e-07
# Don't make swap.
# Bad swap, probability of making the swap: 0.041319055739432474
# Don't make swap.
# Bad swap, probability of making the swap: 0.015839028353494794
# Don't make swap.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-0552705ac4f8> in <module>
#      54         ### Check contiguity
#      55         prec_shape = df2.loc[df2.loc_prec==row.loc_prec, 'geometry'].values[0]
# ---> 56         remove_shape = curr_shapes.loc[row.district, 'geometry'].difference(prec_shape)
#      57         add_shape = curr_shapes.loc[int(row.neighborof), 'geometry'].union(prec_shape)
#      58
#
# /opt/anaconda3/lib/python3.7/site-packages/shapely/geometry/base.py in difference(self, other)
#     614     def difference(self, other):
#     615         """Returns the difference of the geometries"""
# --> 616         return geom_factory(self.impl['difference'](self, other))
#     617
#     618     def intersection(self, other):
#
# /opt/anaconda3/lib/python3.7/site-packages/shapely/topology.py in __call__(self, this, other, *args)
#      64         self._validate(this)
#      65         self._validate(other, stop_prepared=True)
# ---> 66         product = self.fn(this._geom, other._geom, *args)
#      67         if product is None:
#      68             err = TopologicalError(
#
# KeyboardInterrupt:

# %%
plt.scatter(x, y)

# %%
curr_shapes.plot(figsize=(12, 10), column='district', cmap='tab20')
orig_shapes.plot(figsize=(12, 10), column='district', cmap='tab20')

# %%
calc_gmandered_score(curr_scoredf)
# Out:
# 620883.0085308057

# %%
print('min', min(polsby_popper(curr_shapes).tolist()))
print('mean', mean(polsby_popper(curr_shapes).tolist()))
# Out:
# min 0.19030434888518497
# mean 0.2942352613202257

# %%
T
# Out:
# 37.78729765509504

# %%
frozen_count
# Out:
# 0

# %%
#orig_scoredf = final3.copy() Commented out whne doing timeit func.
calc_gmandered_score(final3)
# Out:
# 931975.2995260664

# %% [markdown]
# ### Plot dist partisanness

# %%
def plot_dist_partisaness(curr_districts, curr_dist_shapes):
    #Expensive operation
    curr_dist_shapes["rep_prop"] = curr_districts['rep_prop'].round(3).values
    curr_dist_shapes['coords'] = curr_dist_shapes['geometry'].apply(lambda x: x.representative_point().coords[:])
    curr_dist_shapes['coords'] = [coords[0] for coords in curr_dist_shapes['coords']]
    curr_dist_shapes.plot(figsize=(18, 16),
               column="rep_prop", cmap="coolwarm", legend=True, vmin=0, vmax=1, edgecolor="black", legend_kwds={'shrink': 0.3})
    plt.title("Rep Vote Percentage Per District")
    for idx, row in curr_dist_shapes.iterrows():
        plt.annotate(s=row['district'], xy=row['coords'],
                     horizontalalignment='center')
    plt.axis('off')
    #print(calc_eff_gap(finaldf))

# %%
plot_dist_partisaness(curr_districts, curr_shapes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4224513add55> in <module>
# ----> 1 plot_dist_partisaness(curr_districts, curr_shapes)
#
# NameError: name 'curr_districts' is not defined

# %%
plot_dist_partisaness(orig_districts, orig_shapes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-30d363c67e27> in <module>
# ----> 1 plot_dist_partisaness(orig_districts, orig_shapes)
#
# NameError: name 'orig_districts' is not defined

# %% [markdown]
# ### Save Output to check in Justified Chain

# %%
curr_data[['VTD_num', 'district']].to_csv("620000onACR.txt", sep='\t', header=False, index=False)

# %%
d = {'x':x, 'y': y}
x_y_dataframe = pd.DataFrame(d)
x_y_dataframe.to_csv('620000onACRscatter.txt', sep='\t', header=False, index=False)
